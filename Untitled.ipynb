# %%
import pdbParser
import glob
import pdb
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (200,200)


files = glob.glob('*nspose1.pdb')
print (files)
pdbs = []
#read in files 
for file in files:
    pdbs.append(pdbParser.pdbParser(file))
# Out:
# ['050nspose1.pdb', '100nspose1.pdb', '150nspose1.pdb', '200nspose1.pdb', '250nspose1.pdb', '300nspose1.pdb', '350nspose1.pdb', '400nspose1.pdb', '450nspose1.pdb', '500nspose1.pdb', '550nspose1.pdb', '600nspose1.pdb']

# %%
#3d graph
startChain = pdbs[0].getChains()[0]
startAtoms = startChain.getAtoms()
endChain = pdbs[-1].getChains()[0]
endAtoms = endChain.getAtoms()


posArray = endChain.getPosArray()
xPosEnd = posArray[:,0]
yPosEnd = posArray[:,1]
zPosEnd = posArray[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xPosEnd, yPosEnd, zPosEnd, c='r', marker='o', s=300)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
#Find max distance
distList = []
for key in startAtoms:
    distList.append(startAtoms[key].getDist(endAtoms[key]))
print(distList)

#color points based on distance from start
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.scatter(xPosEnd, yPosEnd, zPosEnd, c= distList, marker='o', s=300)

ax2.set_xlabel('X Label')
ax2.set_ylabel('Y Label')
ax2.set_zlabel('Z Label')
plt.show()
# Out:
# [10.08287131723895, 10.557608441309046, 9.383285192298057, 8.033744892638799, 7.35801841530721, 8.23814578652259, 8.201652028707386, 7.9532577601885865, 8.415474674669277, 8.00081552093285, 10.022353665681527, 6.605366378937656, 7.492811688545231, 7.247724746429048, 5.749041398355035, 4.150671632398784, 4.774415671053372, 11.805251839753357, 12.433880206918513, 13.2659646087271, 12.998574306438382, 14.722551714971148, 15.059597471380165, 13.606267305914582, 16.660411309448513]
